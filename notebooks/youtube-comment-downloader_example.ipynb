# %%
"""

Youtube Comment Downloader:
    https://github.com/egbertbouman/youtube-comment-downloader

"""

# %%
from itertools import islice
from youtube_comment_downloader import *

# %%
downloader = YoutubeCommentDownloader()

# %%
comments = downloader.get_comments_from_url(
    youtube_url='https://www.youtube.com/watch?v='+'GNQRGohdW9Y',
    sort_by=SORT_BY_POPULAR, # SORT_BY_POPULAR, SORT_BY_RECENT
    )

# %%
comments = list(comments)

# %%
comments
# Out:
# [{'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg',
#   'text': 'Americans: "This is a Fight for our Democracy and Constitution." Foreigners: "This is Pure Entertainment."',
#   'time': '2 years ago',
#   'author': 'gigi arnaud',
#   'channel': 'UCpQ-iLF5QPZnInYKHBmHOgA',
#   'votes': '432',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXw3sJJFLVRvfeoto40KIXJobBcl1E2jxsoxg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.604573},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg',
#   'text': 'At least 2020 gave us a month before things started going downhill',
#   'time': '2 years ago',
#   'author': 'Boof',
#   'channel': 'UCv08cwbqgK99wpJofPb1vhQ',
#   'votes': '471',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWdENnWfZoWgmndxb5M8g9-nPV02-EbqKTWBZjq=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.60542},
#  {'cid': 'Ugz8cK8_OZF-WUgSmlJ4AaABAg',
#   'text': 'THANK YOU for releasing an uncut version.  This is much more helpful to citizens like myself, struggling to maintain proper context in a sea of media manipulation.',
#   'time': '2 years ago',
#   'author': 'addusernamehere',
#   'channel': 'UCM8_-DAEBNNq0N-i2e640rQ',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVkPquBKwmTfBf4X8Fb1ZzFOgZXTFycDwRSnQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.606143},
#  {'cid': 'UgxBFtrsU1rZSisK5OV4AaABAg',
#   'text': 'Everyone after 2020: “Oh pls, give me a break.”\n\nbeginning of 2021: “Honey, you got a big storm coming.”',
#   'time': '2 years ago',
#   'author': 'txenxn',
#   'channel': 'UC3BZDCld867PA035ysHCyZA',
#   'votes': '71',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJW1TYqzOuNJZtscWNo30brY1DYZ8jWaKKXfy0nv=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.606836},
#  {'cid': 'Ugx8eQ7_liAPENbwYA94AaABAg',
#   'text': 'Awesome to see people united',
#   'time': '2 years ago',
#   'author': 'Brayan Rodriguez',
#   'channel': 'UCjfXSUqI6zgQkrZXC8Na-Hw',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJU4eVwzoL-etNCliIlCg9yrOv6FRKbl5prVFA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.607493},
#  {'cid': 'Ugz5xXLRcNvvAljjVkV4AaABAg',
#   'text': 'This is the moment when we know who the friends are and who the enemies are.',
#   'time': '1 year ago',
#   'author': 'N N',
#   'channel': 'UCvC_KtT1EDl6HqTIIz2N2ng',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWx1Pb3W5XkGmO8Ts9qKPKY6m6LbZ-9HFAu3ff5NA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1647369532.608398},
#  {'cid': 'UgxdzFyebQyKSNaU3Fh4AaABAg',
#   'text': '2021 is trying to make 2020 look like 1999.',
#   'time': '2 years ago',
#   'author': 'Reginald Zamfury',
#   'channel': 'UCO2tbp8XNkA_FtGp5ZOvq-w',
#   'votes': '362',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWu988eRxQbkZPlpykKwHOOBgNh0NXE32EN3VbCGQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.609181},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg',
#   'text': 'Its seems like 2021 is indeed the real stage and 2020 is just a trailer.',
#   'time': '2 years ago',
#   'author': 'Nathan',
#   'channel': 'UCm5SPnje_jO7JM7ZU32DkZg',
#   'votes': '708',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWvOwjphdFEbxmOsBhQoMr6YcsO0xZvgEfxfjsoPw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.609851},
#  {'cid': 'UgxJdkbw5slqEXVfKXx4AaABAg',
#   'text': "From what I saw here you guys didn't spin this at all and showed the crowd naturally.  If that is fully the case, thank you very much for documenting this and not being part of the problem!",
#   'time': '2 years ago',
#   'author': 'Kyle McEntee',
#   'channel': 'UCffcbLuBXyw742D4inucTpg',
#   'votes': '25',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXZS1K8AV9XHl6sRnXvrPdPt7tGSDpewMyK=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.610526},
#  {'cid': 'UgwuTMWqtr4XrRFTyRZ4AaABAg',
#   'text': '"Nothing in all the world is more DANGEROUS than sincere IGNORANCE and conscientious STUPIDITY."  MLK Jr.',
#   'time': '2 years ago',
#   'author': 'Party Raccoon',
#   'channel': 'UC_uYluZJDIJTHsbsUU7gGKw',
#   'votes': '58',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVToAiPhh1yc9ck5lq02pd7B2dv6i04S5f5xQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.611193},
#  {'cid': 'UgyiLqY4RBBf33fULxB4AaABAg',
#   'text': 'Thank you very much for this coverage.',
#   'time': '2 years ago',
#   'author': 'hl5hl5',
#   'channel': 'UCbvXchyBKR4vUfgGO46ZSHA',
#   'votes': '31',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXTovV01Goiv578SmEOIb639vqs7kPgEofOKmI2=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.611838},
#  {'cid': 'UgxV-jJLmctp38Xq9f54AaABAg',
#   'text': 'What a time we live in for a major historical event to be filmed for the future generations to view in full.',
#   'time': '2 years ago',
#   'author': 'The Willerrd Tree',
#   'channel': 'UC-6-S4u_C_W96kRHBAkI20w',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXFPZ2XcfSZU4_2ooLasFYxS9ZwppfoulORCTfupdKkcbXrXsqb6AW8PiMv011o=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.612477},
#  {'cid': 'UgwcR3T2A0zM8KGI8cd4AaABAg',
#   'text': 'God I’m glad I didn’t say 2021 will be my year',
#   'time': '2 years ago',
#   'author': 'Rxsemary xx',
#   'channel': 'UCYY52BfcU6H9hLmon1A6nNA',
#   'votes': '143',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXJACY8Rb6kd6rNiITZ8NXYkr4AYfJx9SxaLEcVaQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.613056},
#  {'cid': 'UgzSu66hkPcZbY-iyF94AaABAg',
#   'text': '"An Empire toppled by its enemies can rise again. But an empire that falls from within - that\'s dead."\n\n- Zemo, Captain America Civil War',
#   'time': '2 years ago',
#   'author': 'Aman Shukla',
#   'channel': 'UC_wkDbyahX7T12FT4uQajSA',
#   'votes': '139',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJW5afTdJRG3oAR2GbvCsdWtgrtokgA8Po3HAg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.613638},
#  {'cid': 'UgxZhX8WVJ1SnrmGp8d4AaABAg',
#   'text': "'USA' is the best reality show ever. \r\nThe start of the new season 2021 is spectacular.",
#   'time': '2 years ago',
#   'author': 'MömpfLP',
#   'channel': 'UClBRat00nNpfDRvE0Eaec3Q',
#   'votes': '182',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVBd4BL7-3TG12Q6-G6ilehcTM2QJ-htvZ5h6IQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.61422},
#  {'cid': 'UgxLDuA_77d-IIEPyEN4AaABAg',
#   'text': "2020 : Aren't you glad i'm over?\n\n2021 : Hold my Calendar",
#   'time': '2 years ago (edited)',
#   'author': 'macroevolve',
#   'channel': 'UC4jGQnqeZonTXqK2ZpXR_bw',
#   'votes': '46',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXKuvrjpHsdjIKWh-R4pzRg8FLViSJq3V23jui44g=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.614799},
#  {'cid': 'UgyDjKqlqDuhUymmE494AaABAg',
#   'text': 'Thank you for providing this comprehensive video coverage!',
#   'time': '2 years ago',
#   'author': 'Jon Antis',
#   'channel': 'UC_viuCzkOMZalFk_-8oViDw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWyzS8F_pu-b9oMiO6_rDnpX6QoHsFbaMh5e8T5=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.615383},
#  {'cid': 'Ugzk5y9px5_8Uu82zmJ4AaABAg',
#   'text': 'Watching America Fall Apart Right Before My Eyes',
#   'time': '2 years ago',
#   'author': 'courtney young',
#   'channel': 'UCsfh1qxjdYkBnjplsFixtWQ',
#   'votes': '8',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXUgHa6PRkJp-Cf1buvpeKVPhp0pD8ft7zftg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.615971},
#  {'cid': 'UgxTg14FVnAz9isRB7d4AaABAg',
#   'text': 'And I thought my republic had problems',
#   'time': '2 years ago (edited)',
#   'author': 'Mav',
#   'channel': 'UCK_pj_S_Of04B3OAmxMJ4iw',
#   'votes': '1.2K',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUVpaRQ-EIDgNz0waSfBJsKQZz6QSZ6jB7ufOjIpQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.616547},
#  {'cid': 'UgwFW5FHUA0gH0ZaqBx4AaABAg',
#   'text': 'All you Veterans are my Heroes ❤❤❤❤❤❤❤❤',
#   'time': '2 years ago',
#   'author': 'Travis Rehder',
#   'channel': 'UC7kd7f_--TfbWII_h91zzMQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJU3NGKVotq4ag4DtQZT0xHl3j48WOSF2XxjNA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833532.617172},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IDWH1FR7cs',
#   'text': 'Reality TV at its finest.',
#   'time': '2 years ago',
#   'author': 'JD Go',
#   'channel': 'UCB3ULZlnMqptdPWqZ4MXcTQ',
#   'votes': '24',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWU-zop4csZyqw2hkd4opfUFNey2DB5iAU_EA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.910981},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IDZTvoW3iw',
#   'text': "I'm here drinking some Mountain Dew in France, chillin'",
#   'time': '2 years ago',
#   'author': 'whatever_ImAGirl',
#   'channel': 'UCywyC_iWOCy3mRlJJdmeFvw',
#   'votes': '18',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXtjmK-KBakPGNTsS2lomleCK6oHXns0Hm8saBRbw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.912263},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IDjzlicS5d',
#   'text': 'Not so.',
#   'time': '2 years ago',
#   'author': 'D Dc',
#   'channel': 'UC8ccehD7TNMxcZRExTRR_xw',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVFtJw3_bArwKWRmd4_W98Kl405gIZVyCaYhw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.913422},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IDrsZdWm29',
#   'text': 'I’m in the UK watching the worse place rip itself apart',
#   'time': '2 years ago',
#   'author': 'michelle mm',
#   'channel': 'UC-QYAMRS5OfrApKIwUUkouQ',
#   'votes': '9',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVYhdH0hfh7PjDm-ncvdP_jGlWO9JBGerqBOnps=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.914578},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IDsNn1AgIE',
#   'text': 'Its not a democracy tho',
#   'time': '2 years ago',
#   'author': 'Casey Helmer',
#   'channel': 'UCdHqJ4vsoOeKpiLWARQMhZQ',
#   'votes': '3',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVRwIu5pfNmorp5of1KX7MGz8nigE5rxZdztVDU6w=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.915685},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IDzbDZUA5z',
#   'text': '\xa0@Land of The Free\xa0 Oh, have you mislaid your freedom somewhere ? I will help you....how does it look ?',
#   'time': '2 years ago',
#   'author': 'vandboeffel',
#   'channel': 'UCeHLFbSbqOkhj6DZcKbLPiA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVhFFiamKbCqy7yiL8X34kSX4yTY07E6tQJvA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.916734},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IE-humhJ90',
#   'text': 'Still can’t compete with democracy of India',
#   'time': '2 years ago',
#   'author': 'LS Singh',
#   'channel': 'UCCd1Rosb2VtYyn43JWX6mxg',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVFWVzjuR73h5ztZGaC3nu1DcRCi4ck2JfUJXDNUQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.917932},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IE-qwFnIND',
#   'text': '\xa0@Arju\xa0 haha agreed.',
#   'time': '2 years ago',
#   'author': 'iiiii',
#   'channel': 'UCm-8u3WzRfE8m2gXzhYPGgw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJX7bJGlhhlrvGQh0n_nSY4DQVUAeygNECh2EeLXFUchOi7jnfoOOthW7mhCLVQa=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.919016},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IEAa4s9BQq',
#   'text': '\xa0@whatever_ImAGirl\xa0 too much sugar in that poison.',
#   'time': '2 years ago',
#   'author': 'gigi arnaud',
#   'channel': 'UCpQ-iLF5QPZnInYKHBmHOgA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXw3sJJFLVRvfeoto40KIXJobBcl1E2jxsoxg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833532.919986},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IEKpZaihn8',
#   'text': '\xa0@whatever_ImAGirl\xa0 My uncle died from drinking Mountain Dew everyday😣',
#   'time': '2 years ago',
#   'author': 'Francina',
#   'channel': 'UC8zSQgNlrQrpKvaoFRAK8mQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXrPCQ7aIpxyx-LFWcHY0gFqzB9dwIduxpUlrdT=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.254021},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IENdBEz3Ls',
#   'text': "\xa0@Land of The Free\xa0 You want freedom? I'll dm it to you. XD",
#   'time': '2 years ago',
#   'author': 'James McCloud',
#   'channel': 'UCmrQkrFlXzbsh-wnrGpe49Q',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJU_KOFghlD__NpFkdHOCzjVVf6wvCKg055dSQ4SWA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.255133},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IESjWJWrKd',
#   'text': 'No it’s the same al over the world',
#   'time': '2 years ago',
#   'author': 'Nick Romeo lemniscat Rijnberg',
#   'channel': 'UC6l2-0SixgJiqV6ImLXiMrQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/Na0eH6k9_4ODoTNi_4-WN5hTVt_jMM5VnXCh5D-0dqCi356U1JLJdM5zK6Kc4wGXs9NeDVBo=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.256119},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IET6zBHsMN',
#   'text': '\xa0@Nick Romeo lemniscat Rijnberg\xa0 i doubt in Austria and Switzerland is the same.',
#   'time': '2 years ago',
#   'author': 'gigi arnaud',
#   'channel': 'UCpQ-iLF5QPZnInYKHBmHOgA',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXw3sJJFLVRvfeoto40KIXJobBcl1E2jxsoxg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.257091},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IEqVka9f7b',
#   'text': 'Pro Trump and Americans be victorious over this matter the truth will prevail. Just do what is right God is in control if leftist will win that will be for temporary only. You will see thy fruit of their labor . Jesus Christ will come to rescue humanity . God bless 🙏 America.',
#   'time': '2 years ago',
#   'author': 'Sunny Smile',
#   'channel': 'UCWbLKZP8oyG8ATtwti37Ppw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVQsk7zetBRtmJt4oCiMLRHTbhCR6CBQ85KtA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.258067},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IEsgqy6Lmr',
#   'text': '\xa0@Sunny Smile\xa0 If rightist will win that also will be temporary. Not all Christians support Trump. God bless 🙏 America.',
#   'time': '2 years ago',
#   'author': 'James McCloud',
#   'channel': 'UCmrQkrFlXzbsh-wnrGpe49Q',
#   'votes': '3',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJU_KOFghlD__NpFkdHOCzjVVf6wvCKg055dSQ4SWA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.259122},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IEtsByQanE',
#   'text': 'a classic comedy',
#   'time': '2 years ago',
#   'author': 'W Day',
#   'channel': 'UCZzAAYwR6kwguau097XBhEw',
#   'votes': '3',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWDVQEnWENxHKMy4nldxLGnmk159cN5XSeAUQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.260135},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IEuayXNi5G',
#   'text': '\xa0@iiiii\xa0 I was being sarcastic lmao',
#   'time': '2 years ago',
#   'author': 'James McCloud',
#   'channel': 'UCmrQkrFlXzbsh-wnrGpe49Q',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJU_KOFghlD__NpFkdHOCzjVVf6wvCKg055dSQ4SWA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.261058},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IEvZCB7M2f',
#   'text': "\xa0@Sunny Smile\xa0 i didn't knew God and Jesus are involving in politics.",
#   'time': '2 years ago',
#   'author': 'gigi arnaud',
#   'channel': 'UCpQ-iLF5QPZnInYKHBmHOgA',
#   'votes': '4',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXw3sJJFLVRvfeoto40KIXJobBcl1E2jxsoxg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.261893},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IF3pSn_7ld',
#   'text': '\xa0@Sunny Smile\xa0 Ashli Babbit made the most beautiful tribute to President Trump as she died on the floor.  By soiling herself as the life ebbed out of her body......  if only she was wearing one of Donny’s diapers.',
#   'time': '2 years ago',
#   'author': 'Tom Thomassony',
#   'channel': 'UCqbbBc6kFM_fuZy118dATwg',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVVi7h0vHBpn8i5FCU-ImfeShq6EbYNfbknYA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.262714},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IFHSmVrB9U',
#   'text': 'Demonoracy and obama health care....eutanasia....mandatory ....in constitution..',
#   'time': '2 years ago',
#   'author': 'Galiano Valentin',
#   'channel': 'UCZUwdG3dNPAKzktqJCYAusg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWQfnnNn9i6BoCr-Xj50XCP3x1WXpxO5r1xFza3eA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.263519},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IGVBNHhW4_',
#   'text': 'Foreigners: we got more money from the stimulus package lol',
#   'time': '2 years ago',
#   'author': 'SeedPlanter',
#   'channel': 'UC_Br0jT0V5wkMh0w_w58Cuw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXVXJKnFB3um831nk6nwKx1uf4ratHiCJbYsZ2j=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.26433},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IGz6GdtFUE',
#   'text': "\xa0@whatever_ImAGirl\xa0 I'm an American chillin' in my home watching what's going on in the capital :D, ey this is entertaining for me too",
#   'time': '2 years ago',
#   'author': 'CrackerTweek',
#   'channel': 'UCH-_6BqQvkBIV2rScwlNiWA',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWsHHtEM65mDmXyKNR2ecRsTPHu6dssb6H9ZA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.265146},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IHMZ0s9D0Y',
#   'text': 'What happens in America affects all of us, even non Americans',
#   'time': '2 years ago',
#   'author': 'Our Blessed Tribe',
#   'channel': 'UCpMpH3CslLte3waTHCxcBAg',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVOB8l_owqa3hsWCUMwxENRLy6uXbkEYVUqJ2WnHg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.26595},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IJMQ2qECtO',
#   'text': 'TheLightReports.com from what hospital do you type ?',
#   'time': '2 years ago',
#   'author': 'gigi arnaud',
#   'channel': 'UCpQ-iLF5QPZnInYKHBmHOgA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXw3sJJFLVRvfeoto40KIXJobBcl1E2jxsoxg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.26675},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IJwlv3Hfkv',
#   'text': 'TheLightReports.com blah blah. Go home Alex Jones wanna be.',
#   'time': '2 years ago',
#   'author': 'iiiii',
#   'channel': 'UCm-8u3WzRfE8m2gXzhYPGgw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJX7bJGlhhlrvGQh0n_nSY4DQVUAeygNECh2EeLXFUchOi7jnfoOOthW7mhCLVQa=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.267528},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IPgNe5o_CJ',
#   'text': '\xa0@Sunny Smile\xa0 Jesus was a leftist.',
#   'time': '2 years ago',
#   'author': 'B Renee',
#   'channel': 'UCJ6YdnYib7oaI0ThqQwX6iw',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/WUSPjHvFnASiU40_J1Ss70_gEbQcKd5tNuMhimOm-Zp6qQxk6-9vcM_SzeC2bsylAH0JXsUW=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.268242},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IQHzBx_9zC',
#   'text': '\xa0@Casey Helmer\xa0 iTs A RePUbLiC',
#   'time': '2 years ago',
#   'author': 'Downstream01',
#   'channel': 'UCT-zusOlr5EgdfPuS4rNrOw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWqgD_2zxmnC_37qFZ7Ph1-2H0TScLYNrH0VbMrhg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.269023},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IQrtu3FoNY',
#   'text': 'Certainly is',
#   'time': '2 years ago',
#   'author': 'Gor eil',
#   'channel': 'UCWJIGgy8F8woxOCpu1qKUTg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXWXLxjN3_k3Veke7BgCn30sg-Tm8HYxB868w=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.269872},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IVj-U6vAhN',
#   'text': '\xa0@B Renee\xa0 your evidence is astonishing.',
#   'time': '2 years ago',
#   'author': 'gigi arnaud',
#   'channel': 'UCpQ-iLF5QPZnInYKHBmHOgA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXw3sJJFLVRvfeoto40KIXJobBcl1E2jxsoxg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.270636},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19IXu9Y00nuT',
#   'text': 'As a an American I’m WAITING for something to happen. Chillen with my Heath bar',
#   'time': '2 years ago',
#   'author': 'Naudya Yanno, SRNA',
#   'channel': 'UCxPULW-MDSPNUKGrBF3s7qg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWa_8DnO2Ygk4hGiyMewf2KmyAITlPTWpAxbZZYag=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.271373},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19ItdDoD6-_B',
#   'text': "What's pure entertainment for you guys, is a living nightmare in realities like Russia, and Belarus, and China. At least we are able to protest",
#   'time': '2 years ago',
#   'author': 'Random American',
#   'channel': 'UCQBu8v8OImQnyXHAmuRwVCA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWMXXRDv5kFenWQ-B-Sm7ss_cucb4hyv5YxuzfTZ0w=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.272114},
#  {'cid': 'Ugw378VgIkBvqOHdnQh4AaABAg.9IDMmLV_9s19LZTWxuHqy8',
#   'text': 'lul',
#   'time': '1 year ago',
#   'author': 'OminousImpression',
#   'channel': 'UCqJMs6TD7i957qTPs2twxmw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJU8SJebFuPxHGDwwWPbyLgi21kq6XDXfT9co3oPYw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1647369533.272844},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9ICZyQpKqaM',
#   'text': 'not even a month but a week lol',
#   'time': '2 years ago',
#   'author': 'Lina Houji',
#   'channel': 'UCKYUH6ItuS7_6CdZi-kLFSA',
#   'votes': '22',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVrs5eY7lVHEOn_XQKOyJPFA78rXMUZlYNygw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.535244},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9ICfescF4R7',
#   'text': '\xa0@Lina Houji\xa0 hes talking about last year xD',
#   'time': '2 years ago',
#   'author': 'ProfJeffy',
#   'channel': 'UCqb-VdsDhTdnkUHAiUrRbMg',
#   'votes': '13',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUdsp7gcgcYqu2UhKa9ya34BhcpHNZ0IcLCwYYhsOE=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.535864},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9ICfmo2yl8J',
#   'text': 'How do you figure?',
#   'time': '2 years ago',
#   'author': 'G-Girl',
#   'channel': 'UC-m8LNZBWVTU-DhfjaQ98Ew',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUEBkG-Yt4LODsS7ydlZyeymf8j3PhABLmGFLTw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.536412},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9ICgCXxOS1s',
#   'text': '\xa0@ProfJeffy\xa0 lmao ok',
#   'time': '2 years ago',
#   'author': 'Lina Houji',
#   'channel': 'UCKYUH6ItuS7_6CdZi-kLFSA',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVrs5eY7lVHEOn_XQKOyJPFA78rXMUZlYNygw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.536955},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9ICgZ63Nv1z',
#   'text': 'Not even a month. World War was trending last year just a day after the new years day lol',
#   'time': '2 years ago',
#   'author': 'ヅRainyRei',
#   'channel': 'UCDvmplgGAhixYPi4VGhESEw',
#   'votes': '20',
#   'photo': 'https://yt3.ggpht.com/KKnYmaxVnZMdZ-H1NcZDnbJAZhRxeu5Zt_AtoWQVgzbc3Jz4aR1NP0NSCe1J8-x8hIjps4nEsQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.537493},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IChJgOqsJX',
#   'text': 'to be fair this is just carried over momentum from 2020. last year it took a month to pick up the pace.',
#   'time': '2 years ago',
#   'author': "FvckYoutube'sCensorshipAndTheirAdBuyers UseAdblock",
#   'channel': 'UCzuMGwt4P9hhnyLZzLF1Igw',
#   'votes': '4',
#   'photo': 'https://yt3.ggpht.com/kZChB2EloZQMqpd9nLhb2MLJFvda1j_fuJQsAyclFxSb0OBzXJRPYjY2LC3t17YM3QI2afnegKQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.538028},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IDR1eBR2VV',
#   'text': 'you forget the potential war between the USA and Iran',
#   'time': '2 years ago',
#   'author': 'Michael Ola',
#   'channel': 'UCK88dPxX622ZTH9WCfvzMDQ',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVd4z9TjiDKxuwsGQZY9s72sdDaERP0y_ss=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.538559},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IDZuIAH7TZ',
#   'text': 'Started already went down in 2016 !',
#   'time': '2 years ago',
#   'author': 'F.J Gouda',
#   'channel': 'UCDvrHKhyUylIyvloRAepOoA',
#   'votes': '3',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVtLV-oEVAsK4XK7C2_GF3soOKDNQZV8y5N2Q=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.539342},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IDbPi0nzoI',
#   'text': "Lucky that I'm not American",
#   'time': '2 years ago',
#   'author': 'Banjo Tiki',
#   'channel': 'UCeYwq_ujJQDHLhc7wmhR-fg',
#   'votes': '3',
#   'photo': 'https://yt3.ggpht.com/mu5NXpwoxH670p6ARambNyohvdwNiO6PegF6lqYChEVKqgrr7YI1EEvCj22Fy6KKrPwJHqX62A=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.539917},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IDboawydAO',
#   'text': "\xa0@Banjo Tiki\xa0 Me neither ! I'm Dutch. Living in The Netherlands !",
#   'time': '2 years ago',
#   'author': 'F.J Gouda',
#   'channel': 'UCDvrHKhyUylIyvloRAepOoA',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVtLV-oEVAsK4XK7C2_GF3soOKDNQZV8y5N2Q=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.540427},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IDjzL7ATQW',
#   'text': 'NO!!! The first day of 2020 trump said he was gonna start WW3',
#   'time': '2 years ago',
#   'author': 'See🦋',
#   'channel': 'UCH58-Uh7Od1RkZbZfcYxt-w',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/36vvbH8jO1enAwADTD-UMZ14amxVgKvOQZNSJE8_9IBbFn8FnZDR3Ovc88sXM5WU2Zecll5o=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.866739},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IEMFUr9xLA',
#   'text': '"This virus outbreak in China does NOT look normal" - the last week of 2019',
#   'time': '2 years ago',
#   'author': 'Δαίδαλος',
#   'channel': 'UCVkStoXidOc_akz5FG6Q6HQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVW70CSCNLG36aiIKjltwglV_A1yXOr3Arq4DW8=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.867847},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IEe_hFKUev',
#   'text': '\xa0@Banjo Tiki\xa0 luckily it doesnt matter',
#   'time': '2 years ago',
#   'author': 'tom jarvis',
#   'channel': 'UC988hhGVMwhUgIikcaA7TqQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXRRoFPt8e56FxaKWRMWiKtHOwkfFY7gZgrww=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.868824},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IEedWnrlMx',
#   'text': "\xa0@F.J Gouda\xa0doesnt matter, your world is still being f'd equally, i live on a farm",
#   'time': '2 years ago',
#   'author': 'tom jarvis',
#   'channel': 'UC988hhGVMwhUgIikcaA7TqQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXRRoFPt8e56FxaKWRMWiKtHOwkfFY7gZgrww=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.870338},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IFAFolTDHH',
#   'text': "Jason Blackburn tbh I'm not even living in US lmao but I do find it  ridiculous",
#   'time': '2 years ago',
#   'author': 'Lina Houji',
#   'channel': 'UCKYUH6ItuS7_6CdZi-kLFSA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVrs5eY7lVHEOn_XQKOyJPFA78rXMUZlYNygw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.871602},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IFcc8oSwhz',
#   'text': '\xa0@F.J Gouda\xa0 same here bro. Only i am from Rotterdam',
#   'time': '2 years ago',
#   'author': 'Michael Ola',
#   'channel': 'UCK88dPxX622ZTH9WCfvzMDQ',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVd4z9TjiDKxuwsGQZY9s72sdDaERP0y_ss=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.872756},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IGxltdrcis',
#   'text': 'Have you heard of BLM? That’s way worse then this you act like this is a big deal ?!?!',
#   'time': '2 years ago',
#   'author': 'Jacob Tuma',
#   'channel': 'UCdZp4S9tqu8I8u2U-uVyUSg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXmaRbwtM0YZrK2h7a0Xi0zdm-sRcPMY4vfaEpCEQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.873653},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IGy5EspmGM',
#   'text': '\xa0@Jacob Tuma\xa0  It really wasn’t, even the riots weren’t on the same level as this. At least BLM was a good cause, this is just people butthurt Daddy God Emperor Trump isn’t president',
#   'time': '2 years ago (edited)',
#   'author': 'Boof',
#   'channel': 'UCv08cwbqgK99wpJofPb1vhQ',
#   'votes': '4',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWdENnWfZoWgmndxb5M8g9-nPV02-EbqKTWBZjq=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.874508},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IJAPQFWUKJ',
#   'text': '2 months, COVID-19 quarantining did not really start happening until March.',
#   'time': '2 years ago',
#   'author': 'J Rus',
#   'channel': 'UCvEVjjlpWxiDNTASsP21Kuw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXwql1nAuVE0JRtrKz-BhL7TAi1aswh7fLgOWnH=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.875333},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IJBirsUnws',
#   'text': '\xa0@J Rus\xa0 bush fires happened in February',
#   'time': '2 years ago',
#   'author': 'Boof',
#   'channel': 'UCv08cwbqgK99wpJofPb1vhQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWdENnWfZoWgmndxb5M8g9-nPV02-EbqKTWBZjq=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.876158},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9ILRq6HiKbp',
#   'text': "And Trump had knowledge of the virus and riot but didn't warn us",
#   'time': '2 years ago',
#   'author': 'Dah Bajanman',
#   'channel': 'UC78N1UF_uKgylfFiXX033-A',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJV-kwzcZmwTuGnbjrPdHYzUq1veAM2yZTlVA6KDEg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.876962},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IQHcfbeZfu',
#   'text': "It didn't. The airliner shootdown happened on the 8th and that wasn't the first sign.",
#   'time': '2 years ago',
#   'author': 'Downstream01',
#   'channel': 'UCT-zusOlr5EgdfPuS4rNrOw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWqgD_2zxmnC_37qFZ7Ph1-2H0TScLYNrH0VbMrhg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.877775},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IZjO65cvQl',
#   'text': 'As the U.S. falls into more socio-economic ruin, there will be even more riots. As the lyrics of Janis Joplin song go "Freedom is just another name for having nothing to lose".',
#   'time': '2 years ago',
#   'author': 'kansasthunderman1',
#   'channel': 'UCBBYjT8vtHkkfpsJB6ZG1Qg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJW75Ehfpv_qZE-O3OpNiaQAFRUW0rdqJmctN69R=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.878525},
#  {'cid': 'UgwosRzbSy4Ndf3cDJ14AaABAg.9ICNRYT-U4t9IaTxVqezQw',
#   'text': 'Kobe died in January it was all downhill from there',
#   'time': '2 years ago',
#   'author': 'Christen Stroud',
#   'channel': 'UC0WKzTzYqcTR_ikLV7saOUg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUl6GPNC5lj_6o-7SQVhtMnxrBtmT-YRvV_WrvFKw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833533.879271},
#  {'cid': 'UgxBFtrsU1rZSisK5OV4AaABAg.9IEXXmheRaq9IGVcRQBQXn',
#   'text': "Storms been here  and FYI there is no honey Honey. Because there are no bees! But gotta love the faster internet. Actually I haven't even seen any birds.. Oh well , Biden will fix everything I'm sure.",
#   'time': '2 years ago',
#   'author': 'SeedPlanter',
#   'channel': 'UC_Br0jT0V5wkMh0w_w58Cuw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXVXJKnFB3um831nk6nwKx1uf4ratHiCJbYsZ2j=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.127024},
#  {'cid': 'UgxBFtrsU1rZSisK5OV4AaABAg.9IEXXmheRaq9IGxfRb00b5',
#   'text': '\xa0@SeedPlanter\xa0 no if Biden’s president there will be more this bull!',
#   'time': '2 years ago',
#   'author': 'Jacob Tuma',
#   'channel': 'UCdZp4S9tqu8I8u2U-uVyUSg',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXmaRbwtM0YZrK2h7a0Xi0zdm-sRcPMY4vfaEpCEQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.128333},
#  {'cid': 'UgxdzFyebQyKSNaU3Fh4AaABAg.9IC1eMk-mw19ICBVRXafb9',
#   'text': 'It’s looking like the Soviet Union in the late 80s. On the verge of collapse',
#   'time': '2 years ago',
#   'author': 'Brian Is Me',
#   'channel': 'UCV9FXiH6PknBOIq886e7VHw',
#   'votes': '31',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXhY4s7JT-1MxZhpNUShB37pf14mnRsY4_GPFyipw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.390265},
#  {'cid': 'UgxdzFyebQyKSNaU3Fh4AaABAg.9IC1eMk-mw19ICCmUPSrO-',
#   'text': "\xa0@Brian Is Me\xa0 It looks like the Russian Federation in the 90's. Maybe not as bad but getting close to it.",
#   'time': '2 years ago',
#   'author': 'Penguin',
#   'channel': 'UC_tBuHnbyK0h2uin-U4pRnQ',
#   'votes': '8',
#   'photo': 'https://yt3.ggpht.com/dEL4SAOatIDcI6F13UV1Qa7g4h3oSxiBcJbpIkG83VOSffwUsWdDNsVbsaspUdhN6lxVQn0O2zg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.391776},
#  {'cid': 'UgxdzFyebQyKSNaU3Fh4AaABAg.9IC1eMk-mw19ICSjcxp51z',
#   'text': "Let's hope.",
#   'time': '2 years ago',
#   'author': 'Snakeybakey',
#   'channel': 'UCzogRglJ47XR8UD1MAwpzsg',
#   'votes': '5',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWsXsaipTXhx41WoXgYQRCf-ApOFoTWlOr_zmoi=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.392974},
#  {'cid': 'UgxdzFyebQyKSNaU3Fh4AaABAg.9IC1eMk-mw19IDWOaLdAp9',
#   'text': 'American spring ..🤣',
#   'time': '2 years ago',
#   'author': 'Memet Kulolmaz',
#   'channel': 'UCZNhXkUamcGVESbQqc3cORg',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVc5kIU7KeWNk_jICZNGnRFYZjg0xqB1O2i_w=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.39396},
#  {'cid': 'UgxdzFyebQyKSNaU3Fh4AaABAg.9IC1eMk-mw19IDcZgQfsP7',
#   'text': 'noooooo please no more universe!!!!!!',
#   'time': '2 years ago',
#   'author': 'Jennifer P. Chung',
#   'channel': 'UCiO8JC7vuF0tDeFaI-A2lLw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVneo7UgDnoXo-op0EmoRSAGmM0bJ3xbQn4tNI1E0E=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.394971},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IBytoyPais',
#   'text': 'Hypocrisy',
#   'time': '2 years ago',
#   'author': 'mikeakerr27',
#   'channel': 'UCuazFJ6bKhaMvLoc2aiO_GA',
#   'votes': '5',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJW0g6HOny6aVnh64VJswiYLYXK1qZot33_k3g=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.728581},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IBzCeGFu6I',
#   'text': 'nahn nha nha year is just a number',
#   'time': '2 years ago',
#   'author': 'El cura  spammers',
#   'channel': 'UCD003pYxeZHf-x_c5dPIzug',
#   'votes': '11',
#   'photo': 'https://yt3.ggpht.com/tr6Q3Hu4oqWgT7petn4cUamEdhCr_jZQHIfyJshVDNpsrvItimk-ksXvSKTKVvU6DObkjTSQKe0=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.730107},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IBzmUZPr6s',
#   'text': "Yep. 2020, the prologue. Now we have seasons 1 though 9 of the TrumPet 20's",
#   'time': '2 years ago',
#   'author': 'K-aW-tEk "Sleepy Sage" Uni',
#   'channel': 'UCeEX1josBxDvh543-hdKkzQ',
#   'votes': '23',
#   'photo': 'https://yt3.ggpht.com/_tQmgyYqE46FLXkyKz19PQN-J2i1Sm9beS3hKoCXFIELztkRs5MgmWphys3Yi2UkWXyZhXkxUA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.731376},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IBzx-CRn6V',
#   'text': '2019: Loki\n2020: Ultron\n2021 and on: THANOS',
#   'time': '2 years ago',
#   'author': 'innit mate',
#   'channel': 'UCL-sNTBxA57BBHBd6fuwi2Q',
#   'votes': '10',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUcI84cYesu9v-vvBEeGvmKA4LuA1g1v7qvdxkN=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.732538},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IC-ITi-fvj',
#   'text': 'Nah 2020 was just the terms of service',
#   'time': '2 years ago',
#   'author': 'Asher',
#   'channel': 'UCozKb9B9tXrpbbkCm5WiUpw',
#   'votes': '10',
#   'photo': 'https://yt3.ggpht.com/gqKIzJYPcV5LbuORwQLt58TIUHTow8gXz8m-G2Ojo1QV3pPGmDJSsYwgPZS53c2U_qQmJWLo=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.733665},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IC-aFT4kD_',
#   'text': '\xa0@Asher\xa0 And people signed it without even reading it... tut tut',
#   'time': '2 years ago',
#   'author': 'innit mate',
#   'channel': 'UCL-sNTBxA57BBHBd6fuwi2Q',
#   'votes': '3',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUcI84cYesu9v-vvBEeGvmKA4LuA1g1v7qvdxkN=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.734717},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IC0J7Mmze9',
#   'text': 'Its only happening in america the whole world is fine',
#   'time': '2 years ago',
#   'author': 'Redlancelot2',
#   'channel': 'UCYMMhEJoiKPYuhiBErnV1hA',
#   'votes': '4',
#   'photo': 'https://yt3.ggpht.com/q3lxGmZjTnIuU8yWRzfW_6EIFw8wEPo9RJXrAJk34BgkzO_8yAw6BhFzOFwdGM_e_dBOCW98=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.735659},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IC2U18IbQL',
#   'text': 'Keep Believing that',
#   'time': '2 years ago',
#   'author': 'Jeremy Gervais',
#   'channel': 'UC-SkknXo0BOwc4R6jfguKOQ',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUEGggED5EfovorNgUYJ_1_9dU4Ee7wouy4Bg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.736789},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IC37H5jZGX',
#   'text': 'Exactly',
#   'time': '2 years ago',
#   'author': 'L O',
#   'channel': 'UCUWbaTauK0TZaVGamG9T7dg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUJp93LsNrZdR0kWql33LUwSYRC6A1JWOlUyQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833534.737855},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IC3NMh_zEh',
#   'text': '\xa0@Redlancelot2\xa0 true. i want to move to canada. i shouldn’t have to be like “so what is our daily chaos today?” disgusting',
#   'time': '2 years ago',
#   'author': 'aqxa',
#   'channel': 'UCnT8l9fF3J2Ls6XKU9W6WZA',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/tAPS5wpeV58n75-H92lnjFJBYvhE8Kd608_x8_oYeUaY3vU7lhLCCdmX1Ug6T7t6bq5zid6tqA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.197234},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IC76i1C4U4',
#   'text': "\xa0@aqxa\xa0 This is much better than the “pro-democrasy” protests happened in Hong Kong in 2019-20. At least they don't set everythings on fire, attack stores banks, beat up and even killed innocents opposing them for nearly a year. And you don't need a pandemic and national security law to stop them.",
#   'time': '2 years ago',
#   'author': 'Joe Lau',
#   'channel': 'UCYS4MR2K_yBEJQZ9g_y7Ohw',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUvhxohPjb1nqFEEMSuuZvGjuv4HkCpfWzm7Q=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.198497},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICADX3Q7o6',
#   'text': "\xa0@Redlancelot2\xa0 It's most places. Your only hearing about it here on your media sources",
#   'time': '2 years ago',
#   'author': 'The Canada Kid',
#   'channel': 'UCxGf_y2-Bx0hXVMgSYGlYDg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUFjpSk18iwwwnhj1NqC5TGoAc_W0tZNVQ0KA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.199877},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICAt4wSeu3',
#   'text': '2020 was probably  the beginning. Smh',
#   'time': '2 years ago',
#   'author': 'Ty Stewart',
#   'channel': 'UCwSjOtBb3GgVed7tUVscMjg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVZLteiEnYTnKUc6QHMkGtsdMyr8d8SlfQAEw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.200944},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICC-lQpo7W',
#   'text': '\xa0@mikeakerr27\xa0 what? Do you even know what hypocrisy means?',
#   'time': '2 years ago',
#   'author': 'Brian Is Me',
#   'channel': 'UCV9FXiH6PknBOIq886e7VHw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXhY4s7JT-1MxZhpNUShB37pf14mnRsY4_GPFyipw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.201939},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICFwqJp9Gi',
#   'text': "That's not even it's final form yet, and we're out of phoenix downs...",
#   'time': '2 years ago',
#   'author': 'Hardy Joe',
#   'channel': 'UC2ArxgbEI7VReVq8NDRmzsg',
#   'votes': '3',
#   'photo': 'https://yt3.ggpht.com/jGTOCSh-NGYPOHigbr7JSoACEwtqvJTp_ULpBn8uqbRGppMzz4r8g2qI4wmGCGhOFybujpR0tg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.202901},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICFzju-Pdz',
#   'text': '\xa0@K-aW-tEk "Sleepy Sage" Uni\xa0 pls no',
#   'time': '2 years ago',
#   'author': 'Timmering',
#   'channel': 'UCfYvsGgWmlUh7kOBhiBfHUw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/rna7n2_uT0IKyM51lEHSddCU7h5AMOCnfrE7XxvLeNP_ND9UkycjIaMYw4Uqs57ICE4NIRHFwcw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.203847},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICZ7HoWSIx',
#   'text': "Whispers don't",
#   'time': '2 years ago',
#   'author': 'Poe_the_hoe',
#   'channel': 'UCLrPZZj81ytHHPNfmrG2ReA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/mSu50ilZavuDu6pa8Py53cVYpkmZ25VZ4x5py3vnG8cdKigtZvbL9pra-nqXPQM53TOSFOEpwg0=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.204705},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICZWintoGn',
#   'text': '2021 is just 2012 with a twist',
#   'time': '2 years ago',
#   'author': 'ᚨᚱᚦᚢᚱ ᛞᚢᛗ',
#   'channel': 'UC6pW_QWiAttUFX0wZUj4vig',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXXIWnTe7OujdumDx_opTBZ9r4O0YTxnHsi3nL2iUE=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.205557},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICbxEBfqj3',
#   'text': '\xa0@ᚨᚱᚦᚢᚱ ᛞᚢᛗ\xa0 yeah switch the 2 and the 1 and you get 2012 lol',
#   'time': '2 years ago',
#   'author': 'Poe_the_hoe',
#   'channel': 'UCLrPZZj81ytHHPNfmrG2ReA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/mSu50ilZavuDu6pa8Py53cVYpkmZ25VZ4x5py3vnG8cdKigtZvbL9pra-nqXPQM53TOSFOEpwg0=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.206376},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICjPrHgkfm',
#   'text': "Because it's 2020 first",
#   'time': '2 years ago',
#   'author': 'Quant',
#   'channel': 'UCTvYHZXTRfrZFGfsTDUGa7g',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVdWS-BZuGjHCdwSuvrLL3EoVFr_3MYTfp8bzMfKw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.20719},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICklhrrDYf',
#   'text': 'Lez hope, the best is yet to come',
#   'time': '2 years ago',
#   'author': 'nek tro',
#   'channel': 'UCknhLWdmKt3yjAHfYc2rZpA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/U7Bwi-2LTv54tSifCIFGSP8goscemIV8mYsmhe7x-RwC2DhQl7jLlOssjNfdxoMA-epbxzPcvA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.208},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICm4gD25-F',
#   'text': 'Yep, it will be a wild ride.',
#   'time': '2 years ago',
#   'author': 'Margarito Garcia',
#   'channel': 'UCHdtCF9hpXWBavlsT43ZQIg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJW3j6P_ssvJimGVixbWjtMYVMJ087sA8suUbw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.208911},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9ICmH6tKiCu',
#   'text': 'If america falls so does the world economy',
#   'time': '2 years ago',
#   'author': 'Margarito Garcia',
#   'channel': 'UCHdtCF9hpXWBavlsT43ZQIg',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJW3j6P_ssvJimGVixbWjtMYVMJ087sA8suUbw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.209873},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IDEnbRCzLL',
#   'text': 'Well in this case this is made by people',
#   'time': '2 years ago',
#   'author': 'Иван',
#   'channel': 'UCupVWpWOlMEVHY1DGmteabw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVn3MbtJc3jYfXc3xzc3YWJ39APDT2PabGhYUEQFaD8BM-2hjfiA4epzhoORnQjwA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.210754},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IDLUgRsdJ-',
#   'text': '\xa0@Hardy Joe\xa0 You are not lying! LOL.SMH.',
#   'time': '2 years ago',
#   'author': 'Ty Stewart',
#   'channel': 'UCwSjOtBb3GgVed7tUVscMjg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVZLteiEnYTnKUc6QHMkGtsdMyr8d8SlfQAEw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.211591},
#  {'cid': 'UgxrCufIaNISD7tYld94AaABAg.9IBwKNdKIsL9IDYnwfhXXf',
#   'text': "蔡皇 the Chinese government quite literally has concentration camps for Uighurs. You can't compare the situations, they have something to protest, you don't...",
#   'time': '2 years ago',
#   'author': 'freedy 16',
#   'channel': 'UCC9IWd-dRmw6owY2wK8GFIw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXmaEKoiORoBYhZ8lawlBNgqdfAGTc6buEMGSWxdg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833535.212375},
# ...
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXLT1WnkrQXXuNhCe9fuAMdgPwTUHGM9GTgwtNY=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1647369570.639478},
#  {'cid': 'UgyqXSd7aPXd3WVVQ3B4AaABAg',
#   'text': 'Did people really just mix up the Free Hong Kong movement with Trump vs. Biden?',
#   'time': '2 years ago',
#   'author': 'Dr.Danksy',
#   'channel': 'UC62vk_IwRRT3AGoDHBxf4Qg',
#   'votes': '5',
#   'photo': 'https://yt3.ggpht.com/R5rYTn5qrtOQ70igGTAR4dpcBeoOMfPzHux19sVgCJFwIUSJZO4NeRfe6L-5sEc-4s-MuUSgOQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833570.640402},
#  {'cid': 'UgzRYzNYSwBphRjaW_x4AaABAg',
#   'text': 'Rush Limbaugh said this the other day: \'There\'s a lot of people demanding the end of violence...I am glad the men at Lexington and Concord didn\'t feel that way.’ I certainly won’t turn to violence, and haven’t. But I do wonder, amongst all leaders, even trump, saying "violence is never the answer," what do they think of the founders and the Declaration of Independence? Were they just all a bunch of terrorists targeting the valiant UK?\n\n And I think if they’re honest, that’s what they think. And what it means, is this country is gone from a free country to a very repressive empire. And I know that I won’t do violence, if this country goes to a revolution, I’ll leave. But I know there will be people who don’t, because they can’t, and eventually they will be forced to be violent, if the empire represses them enough. Corporations and special interest groups have just stolen the presidential election, because they want the war in Afghanistan to continue, and a lot of other things that are illegal, Trump was putting an end to, like illegal labor, and mass prisons that target the poor and unfortunate, with prison reform. They’ve used Scotus to declare that corporations are people, they bribed all of our Congress members, they’ve bribed scotus to the hilt, and because of that, we now have a de facto corporate and special interest group dictatorship, not a democracy republic. \n\nAnd apparently they all think they’re revolution proof. But the constitution teaches that no nation is. Our politicians need to realize that the more they do injustice the more likely that violence is going to happen, and they will reach a point where nothing can stop it. And if they kill the American people in the face of that, rather than capitulate, then the world will step in, and end them, if needed. It happened to the king of England, it happened to the king of France, it happened to Hitler, and it will happen to our de facto corporate and special interest group, dictatorship, government, that just stole the election. I won’t do it, but somebody will. And if they’re not accepting that reality, then they’re being very stupid. That’s what the founders would say, and the founders would support what those who get violent when there is no other recourse for injustice, are doing, once that gets to be the only recourse for justice. And now that we clearly have a stolen presidential election, it seems we’re getting pretty close. Again, I won’t do anything illegal, I’ll leave. But it worries me that the people running this country now seem to think that this nation is revolution proof, and no one will ever turn to violence, no matter what injustice they pull. The founders turned to violence, and wrote in the Declaration of Independence, that  people have not only the right, but the duty to free themselves from unjust tyranny. Someone will follow what the founders wrote, someone always does, once they have no other choice. \n\nI hope that Congress decides to have televised hearings on all this. Because if Trump is lying he needs to go to prison for the rest of his life, and pay restitution for the harm his lies have caused. But not having hearings makes it look like Congress is censoring the truth that the election was stolen. And even creating that appearance, puts our nation in grave risk of a revolution. It doesn’t matter if people don’t like trump. I don’t like trump. But when a president makes an accusation of such magnitude, failure to investigate it and have the nation reach a consensus, is a grave failure, indeed, one that has the potential to result in many graves. And certainly it would be most tragic, if it was all based on a misunderstanding, that could have all been resolved by examining the evidence in national televised hearings.',
#   'time': '2 years ago (edited)',
#   'author': 'black1582',
#   'channel': 'UCPf8eNRTMLKOtlfNJq7xIvQ',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJW26t2yNtNZFbifmtY5jFcLKuz2xoI8bgqYXQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833570.641343},
#  {'cid': 'UgwTlMJgAW8s-nuwWsZ4AaABAg',
#   'text': 'GOD BLESS OUR PATRIOTS FIGHTING FOR OUR RIGHTS.',
#   'time': '2 years ago',
#   'author': 'TuesdayWells27',
#   'channel': 'UCBE7X08B2qB83oJzFiNOyoQ',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJX8g5J-ewGC2IVxBYC9Is3kLJdPee6oQQK9-jFAsQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833570.642276},
#  {'cid': 'UgyBUflXwXeUcKiMTHV4AaABAg',
#   'text': 'The power of the people is greater than the people in power',
#   'time': '2 years ago',
#   'author': 'Robert Barrett',
#   'channel': 'UCHV5TJKknb3SiiYt1ENxnVw',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXWt06ZUgbjCiGJbVnPM3bPj01lZXTvXx4l_w=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833570.643204},
#  {'cid': 'UgyA_3EaEGeYlG2rH014AaABAg',
#   'text': "That's a super spreader Covid event if ever I saw one.",
#   'time': '2 years ago (edited)',
#   'author': 'drewrommel',
#   'channel': 'UCPhFYQXnRBBtcqk8ZnypY4w',
#   'votes': '5',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVnZCbOIjHb0XtbMtg4SfUzhg9ZhB0IAyzVwCCd=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833570.644135},
#  {'cid': 'Ugx_zuK9_4nvmdLsxgp4AaABAg',
#   'text': '❄❄NEVER GIVE UP❄❄',
#   'time': '2 years ago',
#   'author': 'Keth Zaah NguyenK',
#   'channel': 'UCIRQufB5n7Dd_A0b8KZacvg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWEmOXaV_FzAg-z3hbt1Pa7YkCcXFhnTcP3cMWI=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833570.645103},
#  {'cid': 'Ugx5Q1g3gnSFRbjeRsV4AaABAg',
#   'text': "Why didn't the woman who died comply and listen to the Blue Lives Matters instructions?",
#   'time': '2 years ago',
#   'author': 'Some sort of name',
#   'channel': 'UCWIsa3QM_F25z4imfmJZBkQ',
#   'votes': '23',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUuBpozK3bOGwz36Rq2CRlOCjIJb_JeVmqvTQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833570.646023},
#  {'cid': 'UgzvVtCJ7D5pzMTHdnF4AaABAg',
#   'text': 'Democrats and Republicans need to make peace offerings with each other. \nLet’s just trade our ‘tasty tears’ and ‘not my president’ signs- and show everyone we can work together.',
#   'time': '2 years ago',
#   'author': 'Fredrick Jackson.',
#   'channel': 'UCyLR8QQzgArQxm2eudvb1lQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVotZJNp0-oAUYy1-jUY9FriI2gVgURYbqj3w=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833570.646942},
#  {'cid': 'UgyoHMvJ111S3S4l8894AaABAg.9ID9k-aLkzr9IF5atyDz0q',
#   'text': 'We had our chance.',
#   'time': '2 years ago',
#   'author': 'Michae Michael',
#   'channel': 'UCRHHhnRtE5iffEAgMyoxrmA',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVkTU-zlGcDnfZScobo0x1xeJrtpIt1Ep9Ibg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833570.906594},
#  {'cid': 'UgyoHMvJ111S3S4l8894AaABAg.9ID9k-aLkzr9IGtNLkeoHJ',
#   'text': 'can you imagine what would have happened if these Traitors all show up during the Storm Area 51 Event, A10 Blrrrrrrrrrrrrrrrrrrrrrrrt!',
#   'time': '2 years ago',
#   'author': 'TBI Firefighter',
#   'channel': 'UC0HFoAuNwo8EQgoBNOgxHnA',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVu7yBGDZAuabmww4VwFYBDTE-eElAml6wtldL-Hw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833570.907595},
#  {'cid': 'UgyoHMvJ111S3S4l8894AaABAg.9ID9k-aLkzr9LSSF-3qW9s',
#   'text': 'round 2?',
#   'time': '1 year ago',
#   'author': 'sneaky',
#   'channel': 'UCEv-fNxIaV6FeHYbtnVg_wg',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/sKc5RTHsfEz6HDDOCKNIWMO2kOHBJYt2vec20zpBgNzf15ykpAmjGzHF0zoSSguTg-EFkEeZ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1647369570.90835},
#  {'cid': 'UgyqXSd7aPXd3WVVQ3B4AaABAg.9IC5-_rtm219ICfadh0EK7',
#   'text': 'Both stories tell you “mind your own fking business!”',
#   'time': '2 years ago',
#   'author': 'Jay Liu',
#   'channel': 'UCKjr5kI5nLF89PKq3JT1c1A',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWkAXzErIWtVyuWXYZ5jIxYz2IMfHO-Dud8_Q=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833571.152772},
#  {'cid': 'UgyBUflXwXeUcKiMTHV4AaABAg.9IFf9PePNSE9IIdGy4gQQe',
#   'text': 'If Trumpers were actually people they might have succeeded! Fail! Sad! Also hilarious',
#   'time': '2 years ago',
#   'author': 'sassy puddin',
#   'channel': 'UCZqyTXSyX75x8tFedsp3ugQ',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWccYE7MqQTsOoco8zrUcyAuVt8UaMGWj6evA7V=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833571.379532},
#  {'cid': 'UgyA_3EaEGeYlG2rH014AaABAg.9ICzcHfjjH59IJBlgakeHX',
#   'text': 'Absolutely.  My immediate impression too.',
#   'time': '2 years ago',
#   'author': 'Kelly Garnet',
#   'channel': 'UC5bStC6hYsEolmsumNRQKew',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJVwljXBT2ABX8SgT4CGvcHFOuecI1mKnF6Taw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833571.592647},
#  {'cid': 'Ugx5Q1g3gnSFRbjeRsV4AaABAg.9ICKWyh7PbK9ICQsFjSCrl',
#   'text': 'Some sort of name you mean she should have just complied to what the police said and she wouldn’t have had a problem? They can’t have it both ways.',
#   'time': '2 years ago',
#   'author': 'C K',
#   'channel': 'UCdPeAz6cbSe4DpF1Zx-wowQ',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXxWqUyY7XRJcVZS7RguFEhdnCW7tlI0QOGB3g5kw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833571.851306},
#  {'cid': 'Ugx5Q1g3gnSFRbjeRsV4AaABAg.9ICKWyh7PbK9ICW0ABJBXT',
#   'text': "Watch the actual clip.  It's available on Infowars. Com. She was un armed, and executed by DC police.",
#   'time': '2 years ago',
#   'author': 'William Love',
#   'channel': 'UCD5xu5UR5HDC_xT7vEh5yMg',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJX1PekjpmZM9wRDXV8MpOYJDFH2DJTEtW_3x6KW=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833571.852871},
#  {'cid': 'Ugx5Q1g3gnSFRbjeRsV4AaABAg.9ICKWyh7PbK9ICX1QpNI2s',
#   'text': "\xa0@William Love\xa0 she was trespassing that's reason enough. She broke the law the minute she didn't comply with police orders and stepped foot into the Capitol Building...",
#   'time': '2 years ago',
#   'author': 'Chuck Master',
#   'channel': 'UCCHRKYQ8ZEWgDOcNdMkiEqg',
#   'votes': '2',
#   'photo': 'https://yt3.ggpht.com/QMnrV8kbdcbjIXRK_7vfhlxLc0ekQwOX76SBWFD7VwIilUWl4vb-eJTBzVXUG_T98kBCfjqgag=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833571.854279},
#  {'cid': 'Ugx5Q1g3gnSFRbjeRsV4AaABAg.9ICKWyh7PbK9ICfonnPc9r',
#   'text': "\xa0@William Love\xa0 yeah but whether or not she was unarmed, she should have listened to the police and everything would've gone okay right? Because that's what you always tell people of colour who are unarmed and come in contact with the police",
#   'time': '2 years ago (edited)',
#   'author': 'Some sort of name',
#   'channel': 'UCWIsa3QM_F25z4imfmJZBkQ',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUuBpozK3bOGwz36Rq2CRlOCjIJb_JeVmqvTQ=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833571.855648},
#  {'cid': 'Ugx5Q1g3gnSFRbjeRsV4AaABAg.9ICKWyh7PbK9IF8ci2mt9x',
#   'text': "\xa0@William Love\xa0 oh wait, aren't you mad when BLM protested against Police killing an unarmed black man named George Floyd, or any black unarmed man or woman  for that matter.",
#   'time': '2 years ago',
#   'author': 'Lisa Hudman',
#   'channel': 'UCAddGS9gn7n-fV4Jz80hQyg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJW4QTtjI3n05m3K3jG_uX3qNsRa__TcUi_9yA=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': True,
#   'time_parsed': 1615833571.857007},
#  {'cid': 'UgyxcaIT8_90KYBjufJ4AaABAg',
#   'text': 'The diversity is stoning',
#   'time': '2 years ago',
#   'author': 'no not the Acorn',
#   'channel': 'UCBT2gMd6G6eetTEX95dTPtw',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/qkvxZ7jZybGLcwQrwdTYEOG_ie9rwkeO7_QKdEhTi9FJDe5DLpl77MQOUQ61MdSXKWSGE1y-=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833572.285447},
#  {'cid': 'UgyASEUub3S6MK7x-cF4AaABAg',
#   'text': 'Hang Out Those Skeletons Gee!!! ☠️☠️☠️',
#   'time': '2 years ago',
#   'author': 'Robert S Y Lee',
#   'channel': 'UC9WPBJUm59SR8VcVndB4YAg',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXH7Iu8B3DNh6d7hYnZHQnioS_RrzRSQxkw5g=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833572.287086},
#  {'cid': 'UgxApguAiub1A4OJdHx4AaABAg',
#   'text': 'Every Metallica song lead us all rite here rite now 🇺🇲',
#   'time': '2 years ago',
#   'author': 'J Flow',
#   'channel': 'UCkbSBjdSb2zrgR0jt5yDd_w',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/pa2qI_6ffu2PtTEm4WmqdvqeTsHDKteVV6CqRkwhM5K9IcWb-GEdGUoolzQt9F55NSljOsYDImU=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833572.288492},
#  {'cid': 'UgylU1VtCP3rYRI-qRV4AaABAg',
#   'text': 'The beginning of the revolution.',
#   'time': '2 years ago',
#   'author': 'Deanna Thomas',
#   'channel': 'UCueC17A2_MEC5f8DAZ0arkw',
#   'votes': '3',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWYNdyF6savHl_RCzkv2k7D2iwG-yftAeKtMw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833572.290113},
#  {'cid': 'UgxG2a8-YOkjcNLqT2p4AaABAg',
#   'text': "What's ironic about the whole thing is all they did was help the Democrats win and look good while doing it.",
#   'time': '2 years ago',
#   'author': 'Courtney Wells',
#   'channel': 'UC3XK76ry2qDm6tJwYfM__eg',
#   'votes': '26',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJWWkYmullk2SzzFrfKhuSfW6RYB0nC5OOuHNw=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833572.292522},
#  {'cid': 'Ugw4CcpUWwaOv1RrhoV4AaABAg',
#   'text': 'Canada needs to get it’s bi-planes in the air and defend our border',
#   'time': '2 years ago',
#   'author': 'Michael Frawley',
#   'channel': 'UClLlne-PSG63t3PILarexug',
#   'votes': '1',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJU6vyaK6KMNZENOLtl6be9mcSIlw1H_NZcG_Q=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833572.293937},
#  {'cid': 'Ugy_YT9zmk_fHgboIDl4AaABAg',
#   'text': 'For the pro Trump people that turned out you know there are millions more watching and feeling the same',
#   'time': '2 years ago',
#   'author': 'Alan Partridge',
#   'channel': 'UC1GtVFqEYYf17E9nnMEO3wg',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJUgQecy5lznMayHg-hawBobv6eNJQoGwcJzhg=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833572.295359},
#  {'cid': 'UgxhG4mh-zkONOB96-p4AaABAg',
#   'text': 'how dare they play "were not gona take it" by Twisted Sister',
#   'time': '2 years ago',
#   'author': 'BigBoomer101',
#   'channel': 'UClM-NImKbyVr6C-AhDuR6bw',
#   'votes': '0',
#   'photo': 'https://yt3.ggpht.com/ytc/AL5GRJXJLbj3aEpGn1XGOoO42sAvp0l-y-GJVFFXNVAR=s176-c-k-c0x00ffffff-no-rj',
#   'heart': False,
#   'reply': False,
#   'time_parsed': 1615833572.296834},
#  ...]

# %%
len(comments)
# Out:
# 1971

# %%
for i, comment in enumerate(comments[:10]):
    print(f"{i+1}) {comment['text']}")
# Out:
# 1) Americans: "This is a Fight for our Democracy and Constitution." Foreigners: "This is Pure Entertainment."
# 2) At least 2020 gave us a month before things started going downhill
# 3) THANK YOU for releasing an uncut version.  This is much more helpful to citizens like myself, struggling to maintain proper context in a sea of media manipulation.
# 4) Everyone after 2020: “Oh pls, give me a break.”
#
# beginning of 2021: “Honey, you got a big storm coming.”
# 5) Awesome to see people united
# 6) This is the moment when we know who the friends are and who the enemies are.
# 7) 2021 is trying to make 2020 look like 1999.
# 8) Its seems like 2021 is indeed the real stage and 2020 is just a trailer.
# 9) From what I saw here you guys didn't spin this at all and showed the crowd naturally.  If that is fully the case, thank you very much for documenting this and not being part of the problem!
# 10) "Nothing in all the world is more DANGEROUS than sincere IGNORANCE and conscientious STUPIDITY."  MLK Jr.
